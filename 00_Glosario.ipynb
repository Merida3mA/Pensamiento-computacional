# %% [markdown]
# <a href="https://colab.research.google.com/github/Merida3mA/Pensamiento-computacional/blob/main/00_Glosario.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Glosario
# 1. Division entera `//`
#
# >Es una división entre números donde el resultado es siempre entero porque se redondea al entero menor.
#
# 2. Expresión
#
# >Es una colección de operadores y números.
#
# 3.  Valor
#
# >Es el resultado de una expresión
#
# 4. Error : SyntaxError
#
# >Ocurre cuando llamo una función y cometo un error en su escritura.
# >Ej: abs 42 es un syntaxerror porque no puse paréntesis en el 42. abs(42)
#
# 5. Función `Len`
#
# >Cuenta la cantidad de caracteres de un string.
#
# 6. Error de Tipo (TypeError)
#
# >Cuando se ejecuta una operación que no está asociada a un tipo. ejemplo: '120' / 2
#
# 7. Debugging
#
# >Encontrar y solucionar distintos "bugs" o errores. Se encuentra la línea del error, se corrige y se vuelve a ejecutar
#
# 8. Assignment statment
#
# > Es una instrucción que asigna un valor a una variable
#
# 9. State Diagram
#
# > Representación gráfica del conjunto de variables y los valores que pueden adquirir
#
# 10. Keyword
#
# >Palabra especial para dar estructura a un programa.
#
# 11. Module
#
# >Archivo que contiene código python
#
# 12. Dot operator `.`
#
# >Se usa para acceder a una funcion de un `import`
#
# 13. Evaluate
#
# >Realizar las operaciones de una expresion en orden para obtener su valor
#
# 14. Statement
#
# >lineas de codigo que reprensera un comando o accion
#
# 15. Execute
#
# >hacer exacatemnte lo que indica el codigo
#
# 16. Runtime error
#
# >Error que hace que el prograna no corra antes de siquera el primer ciclo
#
# 17. Exception
#
# >Error que se detecta mientras el programa esta corriendo
#
# 18. Semantic error
#
# >El programa hace algo incorrecto, pero sin mostrar ningun mensaje de error
